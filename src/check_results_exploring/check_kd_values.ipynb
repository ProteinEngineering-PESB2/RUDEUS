# %%
import pandas as pd
import os

import seaborn as sns
import matplotlib.pyplot as plt
import vapeplot

import warnings
warnings.filterwarnings('ignore')

vapeplot.set_palette('avanti')
plt.rc('axes', grid=False, facecolor="white")
plt.rcParams.update({'font.size': 18})

# %%
path_data = "../../training_results/kd_values/"
list_documents = os.listdir(path_data)

# %%
list_df = []

for element in list_documents:
    df_data = pd.read_csv(f"{path_data}{element}")

    name_values = element.split("_exploring")[0]
    df_data['encoder'] = name_values

    list_df.append(df_data)

df_results = pd.concat(list_df, axis=0)
df_results
# Out:
#                         algorithm  fit_time  score_time  test_max_error  \
# 0        GaussianProcessRegressor  0.019684    0.007751     -681.974383
# 1                   BayesianRidge  0.040325    0.006716     -520.192749
# 2                    SGDRegressor  0.314537    0.006234     -589.602159
# 3       GradientBoostingRegressor  2.797967    0.006945     -602.069262
# 4   HistGradientBoostingRegressor  1.519626    0.008744     -532.373888
# ..                            ...       ...         ...             ...
# 9           DecisionTreeRegressor  0.015354    0.002083     -630.597000
# 10                            SVR  0.003460    0.002337     -601.783015
# 11            KNeighborsRegressor  0.001551    0.006638     -545.520580
# 12                  PLSRegression  0.002008    0.002047     -528.468795
# 13                   XGBRegressor  0.356292    0.004611     -613.082414
#
#     test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -125.474141                -57912.231784
# 1                    -112.770890                -40769.658486
# 2                    -121.190865                -44004.324784
# 3                    -124.775065                -51241.440737
# 4                    -123.458445                -44234.427200
# ..                           ...                          ...
# 9                    -123.726809                -57539.862132
# 10                    -92.463455                -53509.685541
# 11                   -110.903870                -41466.618313
# 12                   -123.341452                -44196.481714
# 13                   -110.147892                -47133.587626
#
#     test_neg_median_absolute_error  test_neg_root_mean_squared_error  \
# 0                       -44.216049                       -224.762446
# 1                       -61.938047                       -177.074008
# 2                       -59.817514                       -195.386154
# 3                       -62.193433                       -206.852095
# 4                       -68.879653                       -195.375476
# ..                             ...                               ...
# 9                       -48.814050                       -220.998504
# 10                      -14.297462                       -194.296364
# 11                      -54.338786                       -182.634925
# 12                      -71.451575                       -189.569794
# 13                      -36.953134                       -199.057160
#
#      test_r2  r2_score_value  mean_absolute_error_value  \
# 0  -2.128598        0.059042                 118.816570
# 1  -0.770372        0.207189                 129.114654
# 2  -1.968095        0.183335                 135.316240
# 3  -1.775425        0.174448                 123.881108
# 4  -1.735936        0.287411                 126.715522
# ..       ...             ...                        ...
# 9  -2.086591       -0.540857                 157.191616
# 10 -0.238537       -0.194281                 111.428162
# 11 -1.300340        0.189269                 115.106779
# 12 -1.817691        0.139232                 135.512314
# 13 -1.542357       -0.462192                 145.334319
#
#     mean_squared_error_value  iteration          encoder
# 0                 234.086383         77  prottrans_t5bdf
# 1                 214.870025         77  prottrans_t5bdf
# 2                 218.078609         77  prottrans_t5bdf
# 3                 219.261874         77  prottrans_t5bdf
# 4                 203.709190         77  prottrans_t5bdf
# ..                       ...        ...              ...
# 9                 299.551970         63           bepler
# 10                263.720737         63           bepler
# 11                217.284854         63           bepler
# 12                223.889725         63           bepler
# 13                291.805347         63           bepler
#
# [22400 rows x 14 columns]

# %%
df_results.sort_values(by="mean_squared_error_value")
# Out:
#                 algorithm  fit_time  score_time  test_max_error  \
# 8        BaggingRegressor  0.273139    0.004792   -5.662382e+02
# 9   DecisionTreeRegressor  0.051896    0.003879   -7.677660e+02
# 9   DecisionTreeRegressor  0.121887    0.006076   -6.857660e+02
# 8        BaggingRegressor  0.273329    0.004855   -5.680725e+02
# 9   DecisionTreeRegressor  0.121195    0.006065   -6.929431e+02
# ..                    ...       ...         ...             ...
# 2            SGDRegressor  0.022917    0.007575   -4.962251e+12
# 2            SGDRegressor  0.025734    0.008074   -4.567424e+12
# 2            SGDRegressor  0.021978    0.007399   -4.503325e+12
# 2            SGDRegressor  0.021508    0.007216   -4.611105e+12
# 2            SGDRegressor  0.020012    0.007186   -6.372539e+12
#
#     test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 8                  -1.215450e+02                -4.331030e+04
# 9                  -1.526186e+02                -8.273066e+04
# 9                  -1.468075e+02                -7.540752e+04
# 8                  -1.265603e+02                -4.642559e+04
# 9                  -1.431489e+02                -7.316780e+04
# ..                           ...                          ...
# 2                  -2.616762e+12                -1.006289e+25
# 2                  -1.859669e+12                -7.622456e+24
# 2                  -2.357061e+12                -1.009702e+25
# 2                  -2.372075e+12                -7.895318e+24
# 2                  -3.039112e+12                -1.521153e+25
#
#     test_neg_median_absolute_error  test_neg_root_mean_squared_error  \
# 8                    -6.108188e+01                     -1.971126e+02
# 9                    -5.218330e+01                     -2.678240e+02
# 9                    -3.784312e+01                     -2.547883e+02
# 8                    -7.536105e+01                     -1.991330e+02
# 9                    -2.843550e+01                     -2.555284e+02
# ..                             ...                               ...
# 2                    -2.639857e+12                     -2.907891e+12
# 2                    -1.686927e+12                     -2.247933e+12
# 2                    -2.318987e+12                     -2.637831e+12
# 2                    -2.253150e+12                     -2.636048e+12
# 2                    -2.775774e+12                     -3.420878e+12
#
#          test_r2  r2_score_value  mean_absolute_error_value  \
# 8  -3.130527e+00    4.840936e-01               1.099308e+02
# 9  -5.350288e+00    4.718714e-01               8.916606e+01
# 9  -3.992145e+00    4.415210e-01               8.548421e+01
# 8  -1.936453e+00    4.343140e-01               1.158434e+02
# 9  -4.765608e+00    4.297782e-01               8.847379e+01
# ..           ...             ...                        ...
# 2  -1.942164e+21   -9.773507e+20               7.088384e+12
# 2  -1.489079e+21   -9.774709e+20               6.889395e+12
# 2  -2.648371e+21   -1.043684e+21               6.855051e+12
# 2  -8.586115e+20   -1.256521e+21               8.271012e+12
# 2  -4.802187e+21   -1.606932e+21               9.337226e+12
#
#     mean_squared_error_value  iteration         encoder
# 8               1.733311e+02         40         cpcprot
# 9               1.753722e+02         74         cpcprot
# 9               1.803410e+02         21  prottrans_bert
# 8               1.815009e+02          8         cpcprot
# 9               1.822271e+02         13  prottrans_bert
# ..                       ...        ...             ...
# 2               7.544253e+12         45            esme
# 2               7.544717e+12         47            esme
# 2               7.796065e+12         60            esme
# 2               8.554132e+12         66            esme
# 2               9.673635e+12         69            esme
#
# [22400 rows x 14 columns]
