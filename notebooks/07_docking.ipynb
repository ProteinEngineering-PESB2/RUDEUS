# %%
import sys
sys.path.insert(0, '../rudeus')
from docking.docking import Docking

# %%
dock = Docking(protein_pdb_path="../rudeus_data/bioinformatics_validation/output/protein_1azp_h_renumber.pdb",
        dna_pdb_path="../rudeus_data/bioinformatics_validation/output/dna_1azp_h_renumber_reduced_amber.pdb")
dock.execute_lightdock(steps=10, swarms= 10, glowworms = 200)
# Out:
# @> ProDy is configured: verbosity='none'
# [lightdock3_setup] INFO: Ignoring OXT atoms
# [lightdock3_setup] INFO: Reading structure from protein_1azp_h_renumber.pdb PDB file...
# [lightdock3_setup] INFO: 1094 atoms, 66 residues read.
# [lightdock3_setup] INFO: Ignoring OXT atoms
# [lightdock3_setup] INFO: Reading structure from dna_1azp_h_renumber_reduced_amber.pdb PDB file...
# [lightdock3_setup] INFO: 499 atoms, 16 residues read.
# [lightdock3_setup] INFO: Calculating reference points for receptor protein_1azp_h_renumber.pdb...
# [lightdock3_setup] INFO: Reference points for receptor found, skipping
# [lightdock3_setup] INFO: Done.
# [lightdock3_setup] INFO: Calculating reference points for ligand dna_1azp_h_renumber_reduced_amber.pdb...
# [lightdock3_setup] INFO: Reference points for ligand found, skipping
# [lightdock3_setup] INFO: Done.
# [lightdock3_setup] INFO: Saving processed structure to PDB file...
# [lightdock3_setup] INFO: Done.
# ...
