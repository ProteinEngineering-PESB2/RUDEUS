# %%
import sys
sys.path.insert(0, '../rudeus')
from machine_learning.use_model import UseModel
import pandas as pd

# %%
df = pd.read_csv("../rudeus_data/encoded_data/single_double/prottrans_t5_uniref.csv")
df = df.drop(columns=["type_interaction"])
df
# Out:
#            p_0       p_1       p_2       p_3       p_4       p_5       p_6  \
# 0     0.048092  0.032868 -0.001494 -0.062018 -0.003778  0.011553 -0.003336
# 1     0.001137 -0.036371 -0.001316  0.012051 -0.003318 -0.082171  0.031120
# 2     0.000475  0.011274  0.059589 -0.044880  0.042818 -0.000329 -0.011344
# 3     0.059392  0.048355 -0.012270  0.023485  0.030040  0.052105  0.020916
# 4     0.009994  0.045471  0.057952  0.003034 -0.006978  0.021273 -0.013984
# ...        ...       ...       ...       ...       ...       ...       ...
# 1228  0.007045 -0.006162  0.067712 -0.039342 -0.045674  0.038811 -0.056044
# 1229  0.037221  0.027043  0.015975  0.076492 -0.003602  0.021602 -0.063808
# 1230  0.006880 -0.008367  0.024328  0.037605 -0.037526  0.056906 -0.073287
# 1231  0.062053  0.036159  0.023534  0.074796  0.039753  0.040898 -0.072007
# 1232 -0.023281  0.015620  0.058617 -0.070567  0.030250  0.036481 -0.036506
#
# ...

# %%
use_model = UseModel("../trained_models/single_double/ExtraTreesClassifier_prottrans_t5_uniref.joblib", df)
use_model.predict()
# Out:
# array([1, 1, 0, ..., 0, 0, 0])
