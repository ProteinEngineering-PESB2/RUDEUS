# %%
import sys
sys.path.insert(0, '../rudeus')
import pandas as pd
from machine_learning.model_selection import ModelSelection

# %%
results_path =  "../rudeus_data/training_results/single_double/ml_classic/"
ms = ModelSelection(results_path)
ms.merge_documents()
# Out:
#                      Algorithm        F1    Recall  Precision  Accuracy  \
# 0                          SVC  0.866098  0.866667   0.875047  0.866667
# 1         KNeighborsClassifier  0.841865  0.842667   0.849124  0.842667
# 2    GaussianProcessClassifier  0.890492  0.890667   0.893293  0.890667
# 3                   GaussianNB  0.797252  0.802667   0.837106  0.802667
# 4       DecisionTreeClassifier  0.760961  0.762667   0.769905  0.762667
# ..                         ...       ...       ...        ...       ...
# 5            BaggingClassifier  0.881687  0.881988   0.889707  0.881988
# 6       RandomForestClassifier  0.918930  0.919255   0.930790  0.919255
# 7         ExtraTreesClassifier  0.919049  0.919255   0.927518  0.919255
# 8           AdaBoostClassifier  0.894434  0.894410   0.895080  0.894410
# 9   GradientBoostingClassifier  0.919255  0.919255   0.921030  0.919255
#
#     Iteration             Encoder       Stage
# 0          87    prottrans_albert    Training
# ...

# %%
ms.plot_metrics_by_algorithm()

# %%
ms.plot_metrics_by_num_repr()

# %%
ms.select(12)
# Out:
#                      Algorithm              Encoder  mean_accuracy_training_x  \
# 59        ExtraTreesClassifier  prottrans_t5_uniref                         1
# 60        ExtraTreesClassifier   prottrans_t5_xlu50                         1
# 92   GaussianProcessClassifier   prottrans_t5_xlu50                         1
# 156                        SVC   prottrans_t5_xlu50                         1
#
#      mean_f_score_training_x  mean_precision_training_x  \
# 59                         1                          1
# 60                         1                          1
# 92                         1                          1
# 156                        1                          1
#
#      mean_recall_training_x  mean_accuracy_testing_x  mean_f_score_testing_x  \
# 59                        1                        1                       1
# 60                        1                        1                       1
# ...
